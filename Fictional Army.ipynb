# %% [markdown]
# # Fictional Army - Filtering and Sorting

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Read the csv

# %%
ruta = (r"C:\Users\igbopa\Desktop\REPO TRABAJO\2-Data_Analysis\2-Pandas\Práctica\4-Fictional_Army\army.csv")

# %% [markdown]
# ### Step 3. Create a dataframe and assign it to a variable called army.

# %%
army = pd.read_csv(ruta)
army
# Out:
#     Unnamed: 0    regiment company  deaths  battles  size  veterans  \
# 0            0  Nighthawks     1st     523        5  1045         1
# 1            1  Nighthawks     1st      52       42   957         5
# 2            2  Nighthawks     2nd      25        2  1099        62
# 3            3  Nighthawks     2nd     616        2  1400        26
# 4            4    Dragoons     1st      43        4  1592        73
# 5            5    Dragoons     1st     234        7  1006        37
# 6            6    Dragoons     2nd     523        8   987       949
# 7            7    Dragoons     2nd      62        3   849        48
# 8            8      Scouts     1st      62        4   973        48
# 9            9      Scouts     1st      73        7  1005       435
# 10          10      Scouts     2nd      37        8  1099        63
# 11          11      Scouts     2nd      35        9  1523       345
#
#     readiness  armored  deserters      origin
# ...

# %% [markdown]
# ### Step 4. Set the 'origin' colum as the index of the dataframe

# %%
army = army.set_index("origin")
army
# Out:
#             Unnamed: 0    regiment company  deaths  battles  size  veterans  \
# origin
# Arizona              0  Nighthawks     1st     523        5  1045         1
# California           1  Nighthawks     1st      52       42   957         5
# Texas                2  Nighthawks     2nd      25        2  1099        62
# Florida              3  Nighthawks     2nd     616        2  1400        26
# Maine                4    Dragoons     1st      43        4  1592        73
# Iowa                 5    Dragoons     1st     234        7  1006        37
# Alaska               6    Dragoons     2nd     523        8   987       949
# Washington           7    Dragoons     2nd      62        3   849        48
# Oregon               8      Scouts     1st      62        4   973        48
# Wyoming              9      Scouts     1st      73        7  1005       435
# Louisana            10      Scouts     2nd      37        8  1099        63
# ...

# %% [markdown]
# ### Step 5. Print only the column veterans

# %%
army.loc[:, "veterans"]
# Out:
# 0       1
# 1       5
# 2      62
# 3      26
# 4      73
# 5      37
# 6     949
# 7      48
# 8      48
# 9     435
# 10     63
# 11    345
# Name: veterans, dtype: int64

# %% [markdown]
# ### Step 6. Print the columns 'veterans' and 'deaths'

# %%
army.loc[:,["veterans","deaths"]]
# Out:
#     veterans  deaths
# 0          1     523
# 1          5      52
# 2         62      25
# 3         26     616
# 4         73      43
# 5         37     234
# 6        949     523
# 7         48      62
# 8         48      62
# 9        435      73
# 10        63      37
# 11       345      35

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
army.columns
# Out:
# Index(['Unnamed: 0', 'regiment', 'company', 'deaths', 'battles', 'size',
#        'veterans', 'readiness', 'armored', 'deserters'],
#       dtype='object')

# %% [markdown]
# ### Step 8. Select the 'deaths', 'size' and 'deserters' columns from Maine and Alaska

# %%
army.loc[['Maine', 'Alaska'], ['deaths', 'size', 'deserters']]
# Out:
#         deaths  size  deserters
# origin
# Maine       43  1592          3
# Alaska     523   987         24

# %% [markdown]
# ### Step 9. Select the rows 3 to 7 and the columns 3 to 6

# %%
army.iloc[3:7,3:6]
# Out:
#          deaths  battles  size
# origin
# Florida     616        2  1400
# Maine        43        4  1592
# Iowa        234        7  1006
# Alaska      523        8   987

# %% [markdown]
# ### Step 10. Select every row after the fourth row and all columns

# %%
army.iloc[4: ,:]
# Out:
#             Unnamed: 0  regiment company  deaths  battles  size  veterans  \
# origin
# Maine                4  Dragoons     1st      43        4  1592        73
# Iowa                 5  Dragoons     1st     234        7  1006        37
# Alaska               6  Dragoons     2nd     523        8   987       949
# Washington           7  Dragoons     2nd      62        3   849        48
# Oregon               8    Scouts     1st      62        4   973        48
# Wyoming              9    Scouts     1st      73        7  1005       435
# Louisana            10    Scouts     2nd      37        8  1099        63
# Georgia             11    Scouts     2nd      35        9  1523       345
#
#             readiness  armored  deserters
# origin
# Maine               2        0          3
# Iowa                1        1          4
# Alaska              2        0         24
# Washington          3        1         31
# Oregon              2        0          2
# ...

# %% [markdown]
# ### Step 11. Select every row up to the 4th row and all columns

# %%
army.iloc[:4 ,:]
# Out:
#             Unnamed: 0    regiment company  deaths  battles  size  veterans  \
# origin
# Arizona              0  Nighthawks     1st     523        5  1045         1
# California           1  Nighthawks     1st      52       42   957         5
# Texas                2  Nighthawks     2nd      25        2  1099        62
# Florida              3  Nighthawks     2nd     616        2  1400        26
#
#             readiness  armored  deserters
# origin
# Arizona             1        1          4
# California          2        0         24
# Texas               3        1         31
# Florida             3        1          2

# %% [markdown]
# ### Step 12. Select the 3rd column up to the 7th column

# %%
army.iloc[: , 3:7]
# Out:
#             deaths  battles  size  veterans
# origin
# Arizona        523        5  1045         1
# California      52       42   957         5
# Texas           25        2  1099        62
# Florida        616        2  1400        26
# Maine           43        4  1592        73
# Iowa           234        7  1006        37
# Alaska         523        8   987       949
# Washington      62        3   849        48
# Oregon          62        4   973        48
# Wyoming         73        7  1005       435
# Louisana        37        8  1099        63
# Georgia         35        9  1523       345

# %% [markdown]
# ### Step 13. Select rows where df.deaths is greater than 50

# %%
army[army.loc[:,"deaths"] > 50]
# Out:
#             Unnamed: 0    regiment company  deaths  battles  size  veterans  \
# origin
# Arizona              0  Nighthawks     1st     523        5  1045         1
# California           1  Nighthawks     1st      52       42   957         5
# Florida              3  Nighthawks     2nd     616        2  1400        26
# Iowa                 5    Dragoons     1st     234        7  1006        37
# Alaska               6    Dragoons     2nd     523        8   987       949
# Washington           7    Dragoons     2nd      62        3   849        48
# Oregon               8      Scouts     1st      62        4   973        48
# Wyoming              9      Scouts     1st      73        7  1005       435
#
#             readiness  armored  deserters
# origin
# Arizona             1        1          4
# California          2        0         24
# Florida             3        1          2
# Iowa                1        1          4
# Alaska              2        0         24
# ...

# %% [markdown]
# ### Step 14. Select rows where df.deaths is greater than 500 or less than 50

# %%
army[army.loc[:,"deaths"] > 500 or < 50]
# Out:
#   Cell In[36], line 1
#     army[army.loc[:,"deaths"] > 500 | < 50]
#                                       ^
# SyntaxError: invalid syntax

# %%
army[(army.deaths>500) | (army.deaths<50)]
# Out:
#           Unnamed: 0    regiment company  deaths  battles  size  veterans  \
# origin
# Arizona            0  Nighthawks     1st     523        5  1045         1
# Texas              2  Nighthawks     2nd      25        2  1099        62
# Florida            3  Nighthawks     2nd     616        2  1400        26
# Maine              4    Dragoons     1st      43        4  1592        73
# Alaska             6    Dragoons     2nd     523        8   987       949
# Louisana          10      Scouts     2nd      37        8  1099        63
# Georgia           11      Scouts     2nd      35        9  1523       345
#
#           readiness  armored  deserters
# origin
# Arizona           1        1          4
# Texas             3        1         31
# Florida           3        1          2
# Maine             2        0          3
# Alaska            2        0         24
# Louisana          2        1          2
# Georgia           3        1          3

# %% [markdown]
# ### Step 15. Select all the regiments not named "Dragoons"

# %%
army[army.loc["regiment"] != "Dragoons"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\igbopa\AppData\Local\miniconda3\envs\EDA_ENV\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'regiment'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 1
# ...

# %%
army[(army["regiment"] != "Dragoons")]
# Out:
#             Unnamed: 0    regiment company  deaths  battles  size  veterans  \
# origin
# Arizona              0  Nighthawks     1st     523        5  1045         1
# California           1  Nighthawks     1st      52       42   957         5
# Texas                2  Nighthawks     2nd      25        2  1099        62
# Florida              3  Nighthawks     2nd     616        2  1400        26
# Oregon               8      Scouts     1st      62        4   973        48
# Wyoming              9      Scouts     1st      73        7  1005       435
# Louisana            10      Scouts     2nd      37        8  1099        63
# Georgia             11      Scouts     2nd      35        9  1523       345
#
#             readiness  armored  deserters
# origin
# Arizona             1        1          4
# California          2        0         24
# Texas               3        1         31
# Florida             3        1          2
# Oregon              2        0          2
# ...

# %% [markdown]
# ### Step 16. Select the rows called Texas and Arizona

# %%
army.loc[("Texas","Arizona"),:]
# Out:
#          Unnamed: 0    regiment company  deaths  battles  size  veterans  \
# origin
# Texas             2  Nighthawks     2nd      25        2  1099        62
# Arizona           0  Nighthawks     1st     523        5  1045         1
#
#          readiness  armored  deserters
# origin
# Texas            3        1         31
# Arizona          1        1          4

# %% [markdown]
# ### Step 17. Select the third cell in the row named Arizona

# %%
army.loc[("Arizona"),("deaths")]
# Out:
# 523

# %% [markdown]
# ### Step 18. Select the third cell down in the column named deaths

# %%
army.loc[("Texas"),("deaths")]
# Out:
# 25
